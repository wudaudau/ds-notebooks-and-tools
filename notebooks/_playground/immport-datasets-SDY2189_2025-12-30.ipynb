# %% [markdown]
# # # Objective
#
# Since SDY2011 seems not to have available Olink result data for now, I want to explore the Olink datasets from other studies in ImmPort.
#
# I found SDY2189 should have Olink data according to the query results from ImmPort website (https://www.immport.org/shared/study/SDY2189/studyFiles).
#
# Try to explore SDY2189 dataset using Method 3 from the tutorial notebook `immport-datasets.ipynb`.

# %%
import sys
import os
import pandas as pd

# Set the Python path to the location of the directory containing "immport_download.py"
immport_download_code = "../../immport-data-download-tool/bin/" # Adjust this path as needed
sys.path.insert(0,immport_download_code)
os.chdir(immport_download_code)

import immport_download

# %%
# Configure parameters
user_name = input("ImmPort Username: ")
password = input("ImmPort Password: ")
download_directory = "../../output" # Note: Avoid using parent paths with spaces to prevent potential issues
data_directory = "../../data"

# %% [markdown]
# # Method 3: Using ImmPort API to query and download datasets
